# %% [markdown]
# # Artificial Neural Networks

# %% [markdown]
# #### This ANN contains two hidden layers with 50 neurons each and uses the Sigmoid activation function. The outputs will provide analysis of the accuracy and loss of the network, as well as a frequency tracker for missclassified digits.

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()


# Reshape the data to be in the format (num_samples, 28*28) 
# pictures of numbers are 28x28 pixels
X_train = X_train.reshape((X_train.shape[0], 28 * 28)).astype('float32') / 255
X_test = X_test.reshape((X_test.shape[0], 28 * 28)).astype('float32') / 255

# One-hot encode the target variables
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Define the model
model = Sequential()
num_hidden = 50
model.add(Dense(num_hidden, input_shape=(28 * 28,), activation='sigmoid'))
model.add(Dense(num_hidden, input_shape=(28 * 28,), activation='sigmoid'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Number of sets for training
num_sets = 100

# Training the model
history = model.fit(X_train[:num_sets*1000], y_train[:num_sets*1000], epochs=30, batch_size=200, validation_split=0.2)
# epochs: number of times the entire dataset will be passed forward and backward through the neural network during training
# batch size: the number of samples that will be propagated through the network before the model's parameters are updated
# validation split: splits a fraction of the training data (20%) into a separate validation set

# Plot the learning curve
plt.figure()
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Learning Curve')
plt.legend()
plt.savefig('better_learning_sigmoid.png')
plt.show()

# Evaluate the model on the training set
train_loss, train_acc = model.evaluate(X_train[:num_sets*1000], y_train[:num_sets*1000])
print('Training Loss:', train_loss)
print('Training Accuracy:', train_acc)

# Plot training and validation loss
plt.figure()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Testing Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Testing Loss')
plt.legend()
plt.savefig('better_loss_sigmoid.png')
plt.show()


# Predict labels for the validation set
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Find incorrectly classified digits
incorrect_indices = np.where(y_pred_labels != y_true_labels)[0]
incorrect_digits = y_true_labels[incorrect_indices]

# Count the frequency of incorrectly classified digits
incorrect_digit_counts = np.bincount(incorrect_digits)

# Plot the histogram of incorrectly classified digits
plt.figure()
plt.bar(range(10), incorrect_digit_counts)
plt.xlabel('Digit')
plt.ylabel('Frequency of Misclassification')
plt.title('Frequency of Misclassification for Each Digit')
plt.xticks(range(10))
plt.savefig('better_hist_sigmoid.png')
plt.show()
# Out:
# Epoch 1/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4739 - loss: 1.9955 - val_accuracy: 0.8537 - val_loss: 0.8300
# Epoch 2/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8647 - loss: 0.7032 - val_accuracy: 0.9038 - val_loss: 0.4241
# Epoch 3/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9030 - loss: 0.4013 - val_accuracy: 0.9178 - val_loss: 0.3114
# Epoch 4/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9200 - loss: 0.3063 - val_accuracy: 0.9277 - val_loss: 0.2629
# Epoch 5/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9271 - loss: 0.2633 - val_accuracy: 0.9349 - val_loss: 0.2324
# Epoch 6/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9380 - loss: 0.2214 - val_accuracy: 0.9402 - val_loss: 0.2123
# Epoch 7/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9437 - loss: 0.1980 - val_accuracy: 0.9448 - val_loss: 0.1966
# Epoch 8/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9503 - loss: 0.1780 - val_accuracy: 0.9471 - val_loss: 0.1823
# Epoch 9/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9529 - loss: 0.1682 - val_accuracy: 0.9505 - val_loss: 0.1703
# Epoch 10/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9581 - loss: 0.1487 - val_accuracy: 0.9521 - val_loss: 0.1630
# Epoch 11/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9609 - loss: 0.1415 - val_accuracy: 0.9548 - val_loss: 0.1556
# Epoch 12/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9642 - loss: 0.1262 - val_accuracy: 0.9564 - val_loss: 0.1471
# Epoch 13/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9659 - loss: 0.1221 - val_accuracy: 0.9582 - val_loss: 0.1395
# Epoch 14/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9698 - loss: 0.1096 - val_accuracy: 0.9588 - val_loss: 0.1354
# Epoch 15/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9717 - loss: 0.1005 - val_accuracy: 0.9603 - val_loss: 0.1318
# Epoch 16/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9733 - loss: 0.0944 - val_accuracy: 0.9618 - val_loss: 0.1272
# Epoch 17/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9755 - loss: 0.0883 - val_accuracy: 0.9617 - val_loss: 0.1241
# Epoch 18/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9774 - loss: 0.0853 - val_accuracy: 0.9632 - val_loss: 0.1205
# Epoch 19/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9791 - loss: 0.0775 - val_accuracy: 0.9626 - val_loss: 0.1201
# Epoch 20/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9791 - loss: 0.0729 - val_accuracy: 0.9643 - val_loss: 0.1162
# Epoch 21/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9820 - loss: 0.0663 - val_accuracy: 0.9641 - val_loss: 0.1174
# Epoch 22/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9832 - loss: 0.0618 - val_accuracy: 0.9653 - val_loss: 0.1139
# Epoch 23/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9828 - loss: 0.0615 - val_accuracy: 0.9654 - val_loss: 0.1145
# Epoch 24/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9849 - loss: 0.0565 - val_accuracy: 0.9662 - val_loss: 0.1112
# Epoch 25/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9848 - loss: 0.0567 - val_accuracy: 0.9661 - val_loss: 0.1089
# Epoch 26/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9863 - loss: 0.0497 - val_accuracy: 0.9669 - val_loss: 0.1107
# Epoch 27/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9875 - loss: 0.0494 - val_accuracy: 0.9672 - val_loss: 0.1089
# Epoch 28/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9886 - loss: 0.0441 - val_accuracy: 0.9672 - val_loss: 0.1071
# Epoch 29/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9885 - loss: 0.0439 - val_accuracy: 0.9671 - val_loss: 0.1087
# Epoch 30/30
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9901 - loss: 0.0393 - val_accuracy: 0.9680 - val_loss: 0.1095
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 972us/step - accuracy: 0.9907 - loss: 0.0387
# Training Loss: 0.05144708231091499
# Training Accuracy: 0.9867166876792908
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
